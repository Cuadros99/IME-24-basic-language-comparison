# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
languages = ['python', 'julia', 'c', 'c-otimizado', 'r', 'java']

# %% [markdown]
# ## Host

# %%
frames = []
for lang in languages:
    tmp = pd.read_csv(f'./host/results-host-{lang}.csv')
    tmp.insert(0, 'language', lang)
    frames.append(tmp)
df = pd.concat(frames, ignore_index=True)
df = df.astype({'avg time': float, 'min time': float, 'max time': float, 'std dev': float})

# %%
tmp = df['function name'].str.rsplit('_', n=1, expand=True)
df['function name'] = tmp[0]
df.insert(2, 'instance', tmp[1])

# %%
df
# Out:
#     language                  function name instance    avg time    min time  \
# 0     python                    copy_matrix     5000   12.374828   12.363077
# 1     python                    copy_matrix     7000    0.866607    0.859691
# 2     python                    copy_matrix     9000    1.465662    1.432810
# 3     python          look_and_say_sequence       40    1.009808    0.866428
# 4     python          look_and_say_sequence       45   21.578715   19.641207
# ..       ...                            ...      ...         ...         ...
# 202     java             evaluate_functions    90000   35.387580   35.349273
# 203     java             evaluate_functions   100000   39.085199   39.041656
# 204     java        find_munchausen_numbers        0  469.036960  467.578167
# 205     java        find_pernicious_numbers   100000    0.126978    0.124147
# 206     java  serial_time_series_processing        0    0.000183    0.000040
#
#        max time   std dev
# 0     12.389808  0.013655
# 1      0.872079  0.006319
# 2      1.528046  0.054052
# 3      1.284071  0.237601
# 4     24.093685  2.281718
# ..          ...       ...
# 202   35.423897  0.037352
# 203   39.130725  0.044568
# 204  470.160546  1.323421
# 205    0.130235  0.003066
# 206    0.000452  0.000233
#
# [207 rows x 7 columns]

# %%
pallet = ['#1f77b4', '#ff7f0f', '#8c564b', '#2ca02c']
for func in df['function name'].unique():
    df_test = df.groupby('function name').get_group(func)
    lim = len(df_test['instance'].unique())
    ax = df_test.plot(title=func, legend=False, kind='bar', 
                 x='language', y='avg time', yerr='std dev', 
                 color=pallet[:lim]);
    ax.get_figure().savefig(f'./img_host/{func}.png')
# Out:
# /home/giuliobronson/jupyter/venv/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:386: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
