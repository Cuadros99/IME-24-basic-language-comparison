# %%
import pandas as pd
import dataframe_image as dfi

# %%
languages = ['python', 'c', 'c-otimizado', 'julia', 'r', 'java']
envs = ['host', 'docker', 'vm']

# %%
df = pd.DataFrame()
for env in envs:
    for lang in languages:
        tmp = pd.read_csv(f'./{env}/results-{env}-{lang}.csv')
        tmp.insert(0, 'env', env)
        tmp.insert(1, 'language', lang)
        df = pd.concat([df, tmp], ignore_index=True)

# %%
df
# Out:
#       env language                   function name    avg time    min time  \
# 0    host   python                copy_matrix_5000   12.374828   12.363077
# 1    host   python                copy_matrix_7000    0.866607    0.859691
# 2    host   python                copy_matrix_9000    1.465662    1.432810
# 3    host   python        look_and_say_sequence_40    1.009808    0.866428
# 4    host   python        look_and_say_sequence_45   21.578715   19.641207
# ..    ...      ...                             ...         ...         ...
# 634    vm     java        evaluate_functions_80000  297.143667  295.281000
# 635    vm     java        evaluate_functions_90000  332.028333  331.685000
# 636    vm     java       evaluate_functions_100000  368.135000  367.729000
# 637    vm     java  find_pernicious_numbers_100000    0.013000    0.010000
# 638    vm     java       find_munchausen_numbers_0    4.876504    4.871771
#
#        max time   std dev
# 0     12.389808  0.013655
# 1      0.872079  0.006319
# 2      1.528046  0.054052
# 3      1.284071  0.237601
# 4     24.093685  2.281718
# ..          ...       ...
# 634  298.629000  1.705597
# 635  332.270000  0.305464
# 636  368.565000  0.418516
# 637    0.015000  0.002646
# 638    4.883373  0.006089
#
# [639 rows x 7 columns]

# %%
df['avg time'].astype(float)
# Out:
# 0       12.374828
# 1        0.866607
# 2        1.465662
# 3        1.009808
# 4       21.578715
#           ...
# 634    297.143667
# 635    332.028333
# 636    368.135000
# 637      0.013000
# 638      4.876504
# Name: avg time, Length: 639, dtype: float64

# %%
def maximum_value_in_column(column):    

    highlight = 'background-color: palegreen;'
    default = ''

    maximum_in_column = column.min()

    # must return one string per cell in this column
    return [highlight if v == maximum_in_column else default for v in column]

# %%
tmp = df.groupby('function name')
for func in df['function name'].unique():
    df_test = tmp.get_group(func).drop(columns=['function name', 'min time', 'max time', 'std dev'])
    df_test.style.set_caption(func)
    df_test = pd.pivot(df_test, index=['language'], columns='env', values='avg time') 
    df_test = df_test.style.apply(maximum_value_in_column, subset=['docker', 'host', 'vm'], axis=0)
    dfi.export(df_test, f'./dfs_tests/{func}.png')
# Out:
# /home/rafaelpontes/.local/lib/python3.10/site-packages/dataframe_image/_pandas_accessor.py:69: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   html = '<div>' + obj.render() + '</div>'
# [0616/094840.382338:WARNING:sandbox_linux.cc(376)] InitializeSandbox() called with multiple threads in process gpu-process.
# [0616/094841.646391:WARNING:bluez_dbus_manager.cc(248)] Floss manager not present, cannot set Floss enable/disable.
# [0616/094842.104610:INFO:headless_shell.cc(660)] Written to file /tmp/tmpwjk1q0do/temp.png.
# /home/rafaelpontes/.local/lib/python3.10/site-packages/dataframe_image/_pandas_accessor.py:69: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   html = '<div>' + obj.render() + '</div>'
# [0616/094842.500748:WARNING:sandbox_linux.cc(376)] InitializeSandbox() called with multiple threads in process gpu-process.
# [0616/094844.363528:WARNING:bluez_dbus_manager.cc(248)] Floss manager not present, cannot set Floss enable/disable.
# [0616/094844.800032:INFO:headless_shell.cc(660)] Written to file /tmp/tmpjxg6fiyu/temp.png.
# /home/rafaelpontes/.local/lib/python3.10/site-packages/dataframe_image/_pandas_accessor.py:69: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   html = '<div>' + obj.render() + '</div>'
# [0616/094845.257660:WARNING:sandbox_linux.cc(376)] InitializeSandbox() called with multiple threads in process gpu-process.
# [0616/094846.603417:WARNING:bluez_dbus_manager.cc(248)] Floss manager not present, cannot set Floss enable/disable.
# [0616/094847.012708:INFO:headless_shell.cc(660)] Written to file /tmp/tmp54g5vada/temp.png.
# /home/rafaelpontes/.local/lib/python3.10/site-packages/dataframe_image/_pandas_accessor.py:69: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   html = '<div>' + obj.render() + '</div>'
# [0616/094847.762774:WARNING:sandbox_linux.cc(376)] InitializeSandbox() called with multiple threads in process gpu-process.
# [0616/094849.027317:WARNING:bluez_dbus_manager.cc(248)] Floss manager not present, cannot set Floss enable/disable.
# [0616/094849.453421:INFO:headless_shell.cc(660)] Written to file /tmp/tmpswm2nsmw/temp.png.
# /home/rafaelpontes/.local/lib/python3.10/site-packages/dataframe_image/_pandas_accessor.py:69: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   html = '<div>' + obj.render() + '</div>'
# [0616/094849.941272:WARNING:sandbox_linux.cc(376)] InitializeSandbox() called with multiple threads in process gpu-process.
# [0616/094851.386177:WARNING:bluez_dbus_manager.cc(248)] Floss manager not present, cannot set Floss enable/disable.
# [0616/094851.824200:INFO:headless_shell.cc(660)] Written to file /tmp/tmp7asb6hui/temp.png.
# /home/rafaelpontes/.local/lib/python3.10/site-packages/dataframe_image/_pandas_accessor.py:69: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   html = '<div>' + obj.render() + '</div>'
# [0616/094852.259585:WARNING:sandbox_linux.cc(376)] InitializeSandbox() called with multiple threads in process gpu-process.
# [0616/094854.075447:WARNING:bluez_dbus_manager.cc(248)] Floss manager not present, cannot set Floss enable/disable.
# [0616/094854.522928:INFO:headless_shell.cc(660)] Written to file /tmp/tmpgl0h89a6/temp.png.
# /home/rafaelpontes/.local/lib/python3.10/site-packages/dataframe_image/_pandas_accessor.py:69: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   html = '<div>' + obj.render() + '</div>'
# [0616/094855.561722:WARNING:sandbox_linux.cc(376)] InitializeSandbox() called with multiple threads in process gpu-process.
# [0616/094857.072868:WARNING:bluez_dbus_manager.cc(248)] Floss manager not present, cannot set Floss enable/disable.
# [0616/094857.506065:INFO:headless_shell.cc(660)] Written to file /tmp/tmpo5azjqjn/temp.png.
# /home/rafaelpontes/.local/lib/python3.10/site-packages/dataframe_image/_pandas_accessor.py:69: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   html = '<div>' + obj.render() + '</div>'
# [0616/094858.391636:WARNING:sandbox_linux.cc(376)] InitializeSandbox() called with multiple threads in process gpu-process.
# [0616/094900.165775:WARNING:bluez_dbus_manager.cc(248)] Floss manager not present, cannot set Floss enable/disable.
# [0616/094900.603428:INFO:headless_shell.cc(660)] Written to file /tmp/tmpx0c13mos/temp.png.
# /home/rafaelpontes/.local/lib/python3.10/site-packages/dataframe_image/_pandas_accessor.py:69: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   html = '<div>' + obj.render() + '</div>'
# [0616/094901.059359:WARNING:sandbox_linux.cc(376)] InitializeSandbox() called with multiple threads in process gpu-process.
# [0616/094902.603727:WARNING:bluez_dbus_manager.cc(248)] Floss manager not present, cannot set Floss enable/disable.
# [0616/094903.096143:INFO:headless_shell.cc(660)] Written to file /tmp/tmp73sewucs/temp.png.
# /home/rafaelpontes/.local/lib/python3.10/site-packages/dataframe_image/_pandas_accessor.py:69: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   html = '<div>' + obj.render() + '</div>'
# [0616/094903.459915:WARNING:sandbox_linux.cc(376)] InitializeSandbox() called with multiple threads in process gpu-process.
# [0616/094904.062534:WARNING:bluez_dbus_manager.cc(248)] Floss manager not present, cannot set Floss enable/disable.
# [0616/094904.509324:INFO:headless_shell.cc(660)] Written to file /tmp/tmphux5f0_1/temp.png.
# /home/rafaelpontes/.local/lib/python3.10/site-packages/dataframe_image/_pandas_accessor.py:69: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   html = '<div>' + obj.render() + '</div>'
# [0616/094904.964686:WARNING:sandbox_linux.cc(376)] InitializeSandbox() called with multiple threads in process gpu-process.
# [0616/094905.076117:WARNING:bluez_dbus_manager.cc(248)] Floss manager not present, cannot set Floss enable/disable.
# [0616/094905.555694:INFO:headless_shell.cc(660)] Written to file /tmp/tmpcamfdy8m/temp.png.
# /home/rafaelpontes/.local/lib/python3.10/site-packages/dataframe_image/_pandas_accessor.py:69: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   html = '<div>' + obj.render() + '</div>'
# [0616/094905.989638:WARNING:sandbox_linux.cc(376)] InitializeSandbox() called with multiple threads in process gpu-process.
# [0616/094907.027067:WARNING:bluez_dbus_manager.cc(248)] Floss manager not present, cannot set Floss enable/disable.
# [0616/094907.491444:INFO:headless_shell.cc(660)] Written to file /tmp/tmp3wgtm2b2/temp.png.
# /home/rafaelpontes/.local/lib/python3.10/site-packages/dataframe_image/_pandas_accessor.py:69: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   html = '<div>' + obj.render() + '</div>'
# [0616/094908.760213:WARNING:sandbox_linux.cc(376)] InitializeSandbox() called with multiple threads in process gpu-process.
# [0616/094909.732188:WARNING:bluez_dbus_manager.cc(248)] Floss manager not present, cannot set Floss enable/disable.
# [0616/094910.214503:INFO:headless_shell.cc(660)] Written to file /tmp/tmpzqmsyqqx/temp.png.
# /home/rafaelpontes/.local/lib/python3.10/site-packages/dataframe_image/_pandas_accessor.py:69: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   html = '<div>' + obj.render() + '</div>'
# [0616/