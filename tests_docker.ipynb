# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
languages = ['python', 'julia', 'c', 'c-otimizado', 'r','java']

# %% [markdown]
# ## Docker

# %%
frames = []
for lang in languages:
    tmp = pd.read_csv(f'./docker/results-docker-{lang}.csv')
    tmp.insert(0, 'language', lang)
    frames.append(tmp)
df = pd.concat(frames, ignore_index=True)
df = df.astype({'avg time': float, 'min time': float, 'max time': float, 'std dev': float})

# %%
tmp = df['function name'].str.rsplit('_', n=1, expand=True)
df['function name'] = tmp[0]
df.insert(2, 'instance', tmp[1])

# %%
df
# Out:
#     language            function name instance    avg time    min time  \
# 0     python              copy_matrix     5000   31.026888   30.172638
# 1     python              copy_matrix     7000   58.091175   58.004292
# 2     python              copy_matrix     9000   99.929589   98.732008
# 3     python    look_and_say_sequence       40    1.177920    1.023536
# 4     python    look_and_say_sequence       45   18.671383   17.332790
# ..       ...                      ...      ...         ...         ...
# 209     java       evaluate_functions    80000  295.240667  294.872000
# 210     java       evaluate_functions    90000  331.482667  331.261000
# 211     java       evaluate_functions   100000  367.842667  367.719000
# 212     java  find_pernicious_numbers   100000    0.009667    0.009000
# 213     java  find_munchausen_numbers        0    4.887770    4.872950
#
#        max time   std dev
# 0     31.702420  0.780393
# 1     58.186432  0.091358
# 2    101.030753  1.152402
# 3      1.467020  0.250561
# 4     21.253408  2.236605
# ..          ...       ...
# 209  295.562000  0.347427
# 210  331.656000  0.201887
# 211  368.062000  0.190463
# 212    0.010000  0.000577
# 213    4.915593  0.024112
#
# [214 rows x 7 columns]

# %%
pallet = ['#1f77b4', '#ff7f0f', '#8c564b', '#2ca02c']
for func in df['function name'].unique():
    df_test = df.groupby('function name').get_group(func)
    lim = len(df_test['instance'].unique())
    df_test['final'] = df_test['language'] + ' - ' + df_test['instance']
    print(df_test)
    ax = df_test.plot(logy=True,title=func, legend=False, kind='bar', 
                 x='final', y='avg time', yerr='std dev', 
                 color=pallet[:lim]);
    ax.get_figure().savefig(f'./img_docker/{func}.png')
# Out:
# /tmp/ipykernel_5891/2795644108.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['final'] = df_test['language'] + ' - ' + df_test['instance']
#         language function name instance   avg time   min time    max time  \
# 0         python   copy_matrix     5000  31.026888  30.172638   31.702420
# 1         python   copy_matrix     7000  58.091175  58.004292   58.186432
# 2         python   copy_matrix     9000  99.929589  98.732008  101.030753
# 43         julia   copy_matrix     5000   0.079540   0.078865    0.080569
# 44         julia   copy_matrix     7000   0.155498   0.154920    0.156623
# 45         julia   copy_matrix     9000   0.257092   0.255737    0.258114
# 86             c   copy_matrix     5000   0.146463   0.428497    0.445152
# 87             c   copy_matrix     7000   0.291982   0.428497    0.898975
# 88             c   copy_matrix     9000   0.479046   0.428497    1.441572
# 115  c-otimizado   copy_matrix     5000   0.020218   0.114555    0.129130
# 116  c-otimizado   copy_matrix     7000   0.037883   0.114555    0.229627
# 117  c-otimizado   copy_matrix     9000   0.063602   0.114555    0.394321
# 144            r   copy_matrix     5000  25.175693  13.669380   48.123390
# 145            r   copy_matrix     7000  62.637110  26.386830   87.670890
# 146            r   copy_matrix     9000  86.829910  43.498320  172.185100
# 181         java   copy_matrix     5000   0.147333   0.145000    0.150000
# 182         java   copy_matrix     7000   0.283333   0.282000    0.284000
# 183         java   copy_matrix     9000   0.464333   0.463000    0.466000
#
#        std dev               final
# 0     0.780393       python - 5000
# 1     0.091358       python - 7000
# 2     1.152402       python - 9000
# 43    0.000906        julia - 5000
# 44    0.000974        julia - 7000
# 45    0.001223        julia - 9000
# 86    0.169180            c - 5000
# 87    0.337326            c - 7000
# 88    0.553158            c - 9000
# 115   0.961203  c-otimizado - 5000
# 116   1.026023  c-otimizado - 7000
# 117   1.105355  c-otimizado - 9000
# 144  16.226494            r - 5000
# 145  26.246160            r - 7000
# 146  60.357587            r - 9000
# 181   0.002517         java - 5000
# 182   0.001155         java - 7000
# 183   0.001528         java - 9000
# /tmp/ipykernel_5891/2795644108.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['final'] = df_test['language'] + ' - ' + df_test['instance']
#         language          function name instance     avg time     min time  \
# 3         python  look_and_say_sequence       40     1.177920     1.023536
# 4         python  look_and_say_sequence       45    18.671383    17.332790
# 5         python  look_and_say_sequence       48   221.771429   218.161362
# 46         julia  look_and_say_sequence       40    16.970484    16.864706
# 47         julia  look_and_say_sequence       45   240.045125   237.293206
# 48         julia  look_and_say_sequence       48  1189.502647  1187.289708
# 89             c  look_and_say_sequence       40     0.020120     0.059033
# 90             c  look_and_say_sequence       45     0.074217     0.059033
# 91             c  look_and_say_sequence       48     0.162074     0.059033
# 118  c-otimizado  look_and_say_sequence       40     0.009414     0.054486
# 119  c-otimizado  look_and_say_sequence       45     0.034119     0.054486
# 120  c-otimizado  look_and_say_sequence       48     0.076040     0.054486
# 184         java  look_and_say_sequence       40     0.061075     0.059768
# 185         java  look_and_say_sequence       45     0.082846     0.081098
# 186         java  look_and_say_sequence       48     0.122759     0.122356
#
#         max time   std dev             final
# 3       1.467020  0.250561       python - 40
# 4      21.253408  2.236605       python - 45
# 5     226.358208  4.184799       python - 48
# 46     17.111002  0.126770        julia - 40
# 47    243.100402  2.915459        julia - 45
# 48   1193.161111  3.191473        julia - 48
# 89      0.062930  0.023256            c - 40
# 90      0.223554  0.085700            c - 45
# 91      0.488687  0.187150            c - 48
# 118     0.058883  0.023050  c-otimizado - 40
# 119     0.207159  0.083536  c-otimizado - 45
# 120     0.475060  0.186279  c-otimizado - 48
# 184     0.062389  0.001311         java - 40
# 185     0.085352  0.002226         java - 45
# 186     0.123259  0.000459         java - 48
# /tmp/ipykernel_5891/2795644108.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['final'] = df_test['language'] + ' - ' + df_test['instance']
# /tmp/ipykernel_5891/2795644108.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['final'] = df_test['language'] + ' - ' + df_test['instance']
#     language function name      instance   avg time   min time   max time  \
# 6     python   count_words     bible.txt   0.847738   0.846850   0.848844
# 7     python   count_words     book1.txt   0.164090   0.163956   0.164334
# 8     python   count_words  plrabn12.txt   0.096943   0.096666   0.097428
# 9     python   count_words  world192.txt   0.431308   0.429889   0.432286
# 49     julia   count_words     bible.txt   0.179011   0.177771   0.180531
# 50     julia   count_words     book1.txt   0.046858   0.045985   0.047967
# 51     julia   count_words  plrabn12.txt   0.029081   0.025687   0.032279
# 52     julia   count_words  world192.txt   0.133619   0.133187   0.134022
# 147        r   count_words     bible.txt   8.021537   7.860716   8.219340
# 148        r   count_words     book1.txt   4.098391   4.005103   4.195098
# 149        r   count_words  plrabn12.txt   2.138953   2.130465   2.145140
# 150        r   count_words  world192.txt  24.587750  24.396810  24.707970
# 187     java   count_words     bible.txt   0.750703   0.744161   0.755075
# 188     java   count_words     book1.txt   0.200767   0.197156   0.206808
# 189     java   count_words  plrabn12.txt   0.150915   0.149320   0.153619
# 190     java   count_words  world192.txt   0.402248   0.396137   0.411321
#
#       std dev                  final
# 6    0.001015     python - bible.txt
# 7    0.000212     python - book1.txt
# 8    0.000422  python - plrabn12.txt
# 9    0.001258  python - world192.txt
# 49   0.001401      julia - bible.txt
# 50   0.001012      julia - book1.txt
# 51   0.003300   julia - plrabn12.txt
# 52   0.000418   julia - world192.txt
# 147  0.148725          r - bible.txt
# 148  0.077600          r - book1.txt
# 149  0.006210       r - plrabn12.txt
# 150  0.136517       r - world192.txt
# 187  0.005771       java - bible.txt
# 188  0.005265       java - book1.txt
# 189  0.002354    java - plrabn12.txt
# 190  0.008013    java - world192.txt
#         language        function name instance      avg time      min time  \
# 10        python  iterative_fibonacci       25  5.000000e-06  3.000000e-06
# 12        python  iterative_fibonacci       35  1.066667e-05  4.000000e-06
# 14        python  iterative_fibonacci       45  7.000000e-06  4.000000e-06
# 53         julia  iterative_fibonacci       25  5.640000e-07  9.800000e-08
# 55         julia  iterative_fibonacci       35  5.810000e-07  9.800000e-08
# 57         julia  iterative_fibonacci       45  7.917000e-07  1.160000e-07
# 92             c  iterative_fibonacci       25  0.000000e+00  1.000000e-06
# 93             c  iterative_fibonacci       35  0.000000e+00  1.000000e-06
# 94             c  iterative_fibonacci       45  0.000000e+00  0.000000e+00
# 121  c-otimizado  iterative_fibonacci       25  0.000000e+00  0.000000e+00
# 122  c-otimizado  iterative_fibonacci       35  0.000000e+00  0.000000e+00
# 123  c-otimizado  iterative_fibonacci       45  0.000000e+00  0.000000e+00
# 151            r  iterative_fibonacci       25  5.297162e+00  1.920000e-02
# 153            r  iterative_fibonacci       35  1.629669e+00  1.770000e-02
# 155            r  iterative_fibonacci       45  1.650158e+00  2.320000e-02
# 191         java  iterative_fibonacci       25  1.966667e-06  1.660000e-06
# 193         java  iterative_fibonacci       35  2.103333e-06  1.900000e-06
# 195         java  iterative_fibonacci       45  1.963333e-06  1.900000e-06
#
#       max time       std dev             final
# 10    0.000009  3.464102e-06       python - 25
# 12    0.000020  8.326664e-06       python - 35
# 14    0.000012  4.358899e-06       python - 45
# 53    0.000001  7.693452e-07        julia - 25
# 55    0.000001  7.826551e-07        julia - 35
# 57    0.000002  1.136681e-06        julia - 45
# 92    0.000001  0.000000e+00            c - 25
# 93    0.000001  0.000000e+00            c - 35
# 94    0.000001  0.000000e+00            c - 45
# 121   0.000001  0.000000e+00  c-otimizado - 25
# 122   0.000001  0.000000e+00  c-otimizado - 35
# 123   0.000001  0.000000e+00  c-otimizado - 45
# 151  15.825500  7.444668e+00            r - 25
# 153   4.811444  2.249920e+00            r - 35
# 155   4.857663  2.268128e+00            r - 45
# 191   0.000002  3.324655e-07         java - 25
# 193   0.000002  2.050203e-07         java - 35
# 195   0.000002  1.011599e-07         java - 45
# /tmp/ipykernel_5891/2795644108.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['final'] = df_test['language'] + ' - ' + df_test['instance']
# /tmp/ipykernel_5891/2795644108.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['final'] = df_test['language'] + ' - ' + df_test['instance']
#         language        function name instance     avg time     min time  \
# 11        python  recursive_fibonacci       25     0.120146     0.119255
# 13        python  recursive_fibonacci       35    14.681534    14.634339
# 15        python  recursive_fibonacci       45  1805.905565  1803.078860
# 54         julia  recursive_fibonacci       25     0.000181     0.000180
# 56         julia  recursive_fibonacci       35     0.021617     0.021596
# 58         julia  recursive_fibonacci       45     2.657441     2.625403
# 95             c  recursive_fibonacci       25     0.000055     0.000001
# 96             c  recursive_fibonacci       35     0.006256     0.000001
# 97             c  recursive_fibonacci       45     0.724623     0.000001
# 124  c-otimizado  recursive_fibonacci       25     0.000007     0.000000
# 125  c-otimizado  recursive_fibonacci       35     0.000899     0.000000
# 126  c-otimizado  recursive_fibonacci       45     0.109762     0.000000
# 152            r  recursive_fibonacci       25     1.592947     0.119000
# 154            r  recursive_fibonacci       35     5.370224     0.226000
# 156            r  recursive_fibonacci       45     5.476107     0.246000
# 192         java  recursive_fibonacci       25     0.003126     0.003062
# 194         java  recursive_fibonacci       35     0.038045     0.036986
# 196         java  recursive_fibonacci       45     4.144947     4.136922
#
#         max time   std dev             final
# 11      0.120765  0.000791       python - 25
# 13     14.724962  0.045429       python - 35
# 15   1810.354548  3.899711       python - 45
# 54      0.000182  0.000001        julia - 25
# 56      0.021635  0.000019        julia - 35
# 58      2.676147  0.027876        julia - 45
# 95      0.000351  0.000113            c - 25
# 96      0.038060  0.012771            c - 35
# 97      4.393271  1.479328            c - 45
# 124     0.000103  0.000024  c-otimizado - 25
# 125     0.011011  0.003115  c-otimizado - 35
# 126     1.320817  0.380229  c-otimizado - 45
# 152     4.392380  1.980433            r - 25
# 154    15.439844  7.120860            r - 35
# 156    15.536787  7.115840            r - 45
# 192     0.003168  0.000056         java - 25
# 194     0.038675  0.000922         java - 35
# 196     4.157541  0.011043         java - 45
#         language          function name instance   avg time   min time  \
# 16        python  matrix_multiplication     1500   0.047929   0.033316
# 17        python  matrix_multiplication     1750   0.051367   0.050488
# 18        python  matrix_multiplication     2000   0.077525   0.075856
# 59         julia  matrix_multiplication     1500   0.038258   0.037897
# 60         julia  matrix_multiplication     1750   0.054851   0.054750
# 61         julia  matrix_multiplication     2000   0.083759   0.083162
# 98             c  matrix_multiplication     1500   6.360099  18.626864
# 99             c  matrix_multiplication     1750   9.885475  18.626864
# 100            c  matrix_multiplication     2000  14.836193  18.626864
# 127  c-otimizado  matrix_multiplication     1500   0.287630   1.586255
# 128  c-otimizado  matrix_multiplication     1750   0.470124   1.586255
# 129  c-otimizado  matrix_multiplication     2000   0.685917   1.586255
# 157            r  matrix_multiplication     1500   2.030673   2.020865
# 158            r  matrix_multiplication     1750   3.254968   3.243672
# 159            r  matrix_multiplication     2000   5.104820   5.086322
# 197         java  matrix_multiplication     1500  23.121667  23.012000
# 198         java  matrix_multiplication     1750  36.110667  35.735000
# 199         java  matrix_multiplication     2000  57.250667  57.052000
#
#       max time    std dev               final
# 16    0.074404   0.022970       python - 1500
# 17    0.052681   0.001159       python - 1750
# 18    0.080684   0.002738       python - 2000
# 59    0.038559   0.000335        julia - 1500
# 60    0.055012   0.000141        julia - 1750
# 61    0.084135   0.000523        julia - 2000
# 98   19.868556   7.351110            c - 1500
# 99   30.388697  11.418841            c - 1750
# 100  45.147071  17.136742            c - 2000
# 127   1.964866   0.707105  c-otimizado - 1500
# 128   3.140292   1.155487  c-otimizado - 1750
# 129   4.515763   1.586203  c-otimizado - 2000
# 157   2.045229   0.010500            r - 1500
# 158   3.274510   0.013900            r - 1750
# 159   5.132897   0.020200            r - 2000
# 197  23.252000   0.121327         java - 1500
# 198  36.771000   0.573673         java - 1750
# 199  57.600000   0.303482         java - 2000
# /tmp/ipykernel_5891/2795644108.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['final'] = df_test['language'] + ' - ' + df_test['instance']
# /tmp/ipykernel_5891/2795644108.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['final'] = df_test['language'] + ' - ' + df_test['instance']
#         language       function name instance    avg time    min time  \
# 19        python  belief_propagation      250    3.550026    3.516251
# 20        python  belief_propagation      500    6.909404    6.872311
# 21        python  belief_propagation     1000   13.601912   13.569846
# 62         julia  belief_propagation      250    3.576098    3.529106
# 63         julia  belief_propagation      500    6.855933    6.815782
# 64         julia  belief_propagation     1000   13.434734   13.390571
# 104            c  belief_propagation      250    0.254416    0.759036
# 105            c  belief_propagation      500    0.503081    0.759036
# 106            c  belief_propagation     1000    0.999289    0.759036
# 133  c-otimizado  belief_propagation      250    0.053801    0.318616
# 134  c-otimizado  belief_propagation      500    0.106162    0.318616
# 135  c-otimizado  belief_propagation     1000    0.208643    0.318616
# 160            r  belief_propagation      250    8.197688    7.999211
# 161            r  belief_propagation      500   16.613460   15.961010
# 162            r  belief_propagation     1000   32.558990   30.360640
# 200         java  belief_propagation      250   46.007333   45.338000
# 201         java  belief_propagation      500   90.371667   89.932000
# 202         java  belief_propagation     1000  181.172000  179.537000
#
#        max time   std dev               final
# 19     3.571131  0.029553        python - 250
# 20     6.936701  0.033294        python - 500
# 21    13.619100  0.027794       python - 1000
# 62     3.659795  0.072667         julia - 250
# 63     6.931916  0.065838         julia - 500
# 64    13.464374  0.038986        julia - 1000
# 104    0.768847  0.293784             c - 250
# 105    1.515168  0.580913             c - 500
# 106    3.004169  1.153884            c - 1000
# 133    0.325993  0.127663   c-otimizado - 250
# 134    0.638950  0.252310   c-otimizado - 500
# 135    1.255391  0.498088  c-otimizado - 1000
# 160    8.299047  0.140355             r - 250
# 161   17.761370  0.814217             r - 500
# 162   33.868560  1.563930            r - 1000
# 200   46.380000  0.580904          java - 250
# 201   90.615000  0.381487          java - 500
# 202  183.250000  1.895727         java - 1000
#         language          function name instance  avg time  min time  \
# 22        python  markov_chain_function     5000  0.044005  0.040208
# 23        python  markov_chain_function    10000  0.086562  0.085912
# 24        python  markov_chain_function    15000  0.121039  0.120794
# 65         julia  markov_chain_function     5000  0.000118  0.000114
# 66         julia  markov_chain_function    10000  0.000243  0.000239
# 67         julia  markov_chain_function    15000  0.000366  0.000356
# 107            c  markov_chain_function     5000  0.000275  0.000753
# 108            c  markov_chain_function    10000  0.000534  0.000753
# 109            c  markov_chain_function    15000  0.000782  0.000753
# 136  c-otimizado  markov_chain_function     5000  0.000101  0.000592
# 137  c-otimizado  markov_chain_function    10000  0.000194  0.000592
# 138  c-otimizado  markov_chain_function    15000  0.000287  0.000592
# 163            r  markov_chain_function     5000  0.044100  0.024600
# 164            r  markov_chain_function    10000  0.065900  0.052700
# 165            r  markov_chain_function    15000  0.093000  0.078600
# 203         java  markov_chain_function     5000  0.010667  0.002000
# 204         java  markov_chain_function    10000  0.003667  0.003000
# 205         java  markov_chain_function    15000  0.004667  0.004000
#
#      max time   std dev                final
# 22   0.051195  0.006230        python - 5000
# 23   0.087514  0.000842       python - 10000
# 24   0.121311  0.000260       python - 15000
# 65   0.000123  0.000005         julia - 5000
# 66   0.000248  0.000005        julia - 10000
# 67   0.000379  0.000012        julia - 15000
# 107  0.000950  0.000321             c - 5000
# 108  0.001715  0.000619            c - 10000
# 109  0.002437  0.000904            c - 15000
# 136  0.000624  0.058465   c-otimizado - 5000
# 137  0.001185  0.095488  c-otimizado - 10000
# 138  0.001726  0.139310  c-otimizado - 15000
# 163  0.071900  0.020200             r - 5000
# 164  0.090700  0.017500            r - 10000
# 165  0.117000  0.017400            r - 15000
# 203  0.027000  0.014154          java - 5000
# 204  0.004000  0.000577         java - 10000
# 205  0.005000  0.000577         java - 15000
# /tmp/ipykernel_5891/2795644108.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['final'] = df_test['language'] + ' - ' + df_test['instance']
# /tmp/ipykernel_5891/2795644108.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['final'] = df_test['language'] + ' - ' + df_test['instance']
#     language function name instance   avg time  min time   max time   std dev  \
# 25    python   compute_FFT     1000   0.075181  0.063561   0.097403  0.019251
# 26    python   compute_FFT     3000   0.622961  0.622265   0.624269  0.001133
# 27    python   compute_FFT     5000   1.759103  1.758213   1.760582  0.001289
# 68     julia   compute_FFT     1000   0.048373  0.043179   0.056021  0.006764
# 69     julia   compute_FFT     3000   0.472557  0.424153   0.564823  0.079937
# 70     julia   compute_FFT     5000   1.232011  1.184367   1.320866  0.077018
# 166        r   compute_FFT     1000   0.236763  0.232236   0.244727  0.005650
# 167        r   compute_FFT     3000   2.975742  2.943564   3.018123  0.031300
# 168        r   compute_FFT     5000  10.224660  8.845843  12.699500  1.753781
#
#              final
# 25   python - 1000
# 26   python - 3000
# 27   python - 5000
# 68    julia - 1000
# 69    julia - 3000
# 70    julia - 5000
# 166       r - 1000
# 167       r - 3000
# 168       r - 5000
#         language     function name instance     avg time     min time  \
# 28        python  iterative_solver      100     1.297863     1.287540
# 29        python  iterative_solver      150    12.650407    11.062658
# 30        python  iterative_solver      200    30.611967    29.792936
# 71         julia  iterative_solver      100     0.777233     0.776263
# 72         julia  iterative_solver      150     3.894985     3.893636
# 73         julia  iterative_solver      200    12.148925    12.143692
# 110            c  iterative_solver      100     0.133528     0.395726
# 111            c  iterative_solver      150     0.625570     0.395726
# 112            c  iterative_solver      200     1.916968     0.395726
# 139  c-otimizado  iterative_solver      100     0.030064     0.177412
# 140  c-otimizado  iterative_solver      150     0.140710     0.177412
# 141  c-otimizado  iterative_solver      200     0.423391     0.177412
# 169            r  iterative_solver      100    94.107481    93.312719
# 170            r  iterative_solver      150   446.303400   445.840010
# 171            r  iterative_solver      200  1382.521590  1377.002160
# 206         java  iterative_solver      100     0.349667     0.344000
# 207         java  iterative_solver      150     1.431333     1.426000
# 208         java  iterative_solver      200     3.970000     3.964000
#
#         max time   std dev              final
# 28      1.305377  0.009244       python - 100
# 29     14.875555  1.984756       python - 150
# 30     31.079568  0.711676       python - 200
# 71      0.778581  0.001204        julia - 100
# 72      3.896835  0.001657        julia - 150
# 73     12.152048  0.004559        julia - 200
# 110     0.403172  0.154197            c - 100
# 111     1.884266  0.722353            c - 150
# 112     5.794625  2.213595            c - 200
# 139     0.181913  0.071726  c-otimizado - 100
# 140     0.848835  0.337708  c-otimizado - 150
# 141     2.552678  1.021576  c-otimizado - 200
# 169    94.555470  0.563498            r - 100
# 170   446.540360  0.327706            r - 150
# 171  1385.689430  3.917027            r - 200
# 206     0.355000  0.005508         java - 100
# 207     1.435000  0.004726         java - 150
# 208     3.974000  0.005292         java - 200
# /tmp/ipykernel_5891/2795644108.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['final'] = df_test['language'] + ' - ' + df_test['instance']
# /tmp/ipykernel_5891/2795644108.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['final'] = df_test['language'] + ' - ' + df_test['instance']
#     language function name instance    avg time    min time    max time  \
# 31    python   sqrt_matrix     1000    0.513150    0.442236    0.632610
# 32    python   sqrt_matrix     2000    3.461683    3.397097    3.569542
# 33    python   sqrt_matrix     4000   27.745903   27.460130   28.259870
# 74     julia   sqrt_matrix     1000    0.190803    0.189246    0.193451
# 75     julia   sqrt_matrix     2000    1.117715    1.110521    1.124175
# 76     julia   sqrt_matrix     4000   10.664122   10.538597   10.781229
# 172        r   sqrt_matrix     1000    1.663882    1.634921    1.712021
# 173        r   sqrt_matrix     2000   13.803830   13.748310   13.862430
# 174        r   sqrt_matrix     4000  107.837100  107.679400  107.978100
#
#       std dev          final
# 31   0.104058  python - 1000
# 32   0.094015  python - 2000
# 33   0.446039  python - 4000
# 74   0.002306   julia - 1000
# 75   0.006856   julia - 2000
# 76   0.121535   julia - 4000
# 172  0.034300       r - 1000
# 173  0.046600       r - 2000
# 174  0.122514       r - 4000
#     language       function name instance  avg time  min time  max time  \
# 34    python  compute_quadrature       50  0.010961  0.001266  0.030315
# 35    python  compute_quadrature       75  0.001959  0.001910  0.002025
# 36    python  compute_quadrature      100  0.002645  0.002584  0.002746
# 77     julia  compute_quadrature       50  0.000208  0.000128  0.000361
# 78     julia  compute_quadrature       75  0.000349  0.000272  0.000501
# 79     julia  compute_quadrature      100  0.000519  0.000440  0.000676
# 175        r  compute_quadrature       50  0.004550  0.000454  0.011000
# 176        r  compute_quadrature       75  0.004940  0.000830  0.011500
# 177        r  compute_quadrature      100  0.005560  0.001450  0.012400
#
#       std dev         final
# 34   0.016761   python - 50
# 35   0.000060   python - 75
# 36   0.000088  python - 100
# 77   0.000133    julia - 50
# 78   0.000132    julia - 75
# 79   0.000136   julia - 100
# 175  0.004600        r - 50
# 176  0.004700        r - 75
# 177  0.004900       r - 100
# /tmp/ipykernel_5891/2795644108.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['final'] = df_test['language'] + ' - ' + df_test['instance']
# /tmp/ipykernel_5891/2795644108.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['final'] = df_test['language'] + ' - ' + df_test['instance']
#         language       function name instance    avg time    min time  \
# 37        python  evaluate_functions    80000   31.654466   31.589304
# 38        python  evaluate_functions    90000   35.676647   35.637378
# 39        python  evaluate_functions   100000   40.568447   40.519486
# 80         julia  evaluate_functions    80000   28.449341   28.444162
# 81         julia  evaluate_functions    90000   34.654283   34.651142
# 82         julia  evaluate_functions   100000   36.511888   36.051761
# 101            c  evaluate_functions    80000   23.102297   68.627151
# 102            c  evaluate_functions    90000   25.874085   68.627151
# 103            c  evaluate_functions   100000   28.777080   68.627151
# 130  c-otimizado  evaluate_functions    80000    4.951514   29.248533
# 131  c-otimizado  evaluate_functions    90000    5.481062   29.248533
# 132  c-otimizado  evaluate_functions   100000    6.178303   29.248533
# 178            r  evaluate_functions    80000   32.640790   32.605940
# 179            r  evaluate_functions    90000   36.570890   36.365270
# 180            r  evaluate_functions   100000   40.544240   40.409590
# 209         java  evaluate_functions    80000  295.240667  294.872000
# 210         java  evaluate_functions    90000  331.482667  331.261000
# 211         java  evaluate_functions   100000  367.842667  367.719000
#
#        max time    std dev                 final
# 37    31.746374   0.081880        python - 80000
# 38    35.721887   0.042570        python - 90000
# 39    40.619377   0.049975       python - 100000
# 80    28.457261   0.006967         julia - 80000
# 81    34.658709   0.003944         julia - 90000
# 82    36.908470   0.431875        julia - 100000
# 101   69.706436  26.677693             c - 80000
# 102   78.082800  29.877421             c - 90000
# 103   87.234022  33.231680            c - 100000
# 130   30.159717  12.129633   c-otimizado - 80000
# 131   33.258265  13.426401   c-otimizado - 90000
# 132   37.634370  15.136456  c-otimizado - 100000
# 178   32.703110   0.044200             r - 80000
# 179   36.682650   0.145577             r - 90000
# 180   40.655980   0.101884            r - 100000
# 209  295.562000   0.347427          java - 80000
# 210  331.656000   0.201887          java - 90000
# 211  368.062000   0.190463         java - 100000
#         language            function name instance    avg time    min time  \
# 40        python  find_munchausen_numbers        0  830.275036  827.269027
# 83         julia  find_munchausen_numbers        0    4.248850    4.176494
# 113            c  find_munchausen_numbers        0   12.103947   11.968129
# 142  c-otimizado  find_munchausen_numbers        0    1.424372    2.795797
# 213         java  find_munchausen_numbers        0    4.887770    4.872950
#
#        max time   std dev            final
# 40   834.352477  3.661256       python - 0
# 83     4.286079  0.062671        julia - 0
# 113   12.214883  0.102262            c - 0
# 142    2.897972  2.014385  c-otimizado - 0
# 213    4.915593  0.024112         java - 0
# /tmp/ipykernel_5891/2795644108.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['final'] = df_test['language'] + ' - ' + df_test['instance']
# /tmp/ipykernel_5891/2795644108.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['final'] = df_test['language'] + ' - ' + df_test['instance']
#         language            function name instance  avg time  min time  \
# 41        python  find_pernicious_numbers   100000  0.252427  0.245864
# 84         julia  find_pernicious_numbers   100000  0.002307  0.002238
# 114            c  find_pernicious_numbers   100000  0.004666  0.004379
# 143  c-otimizado  find_pernicious_numbers   100000  0.000558  0.001080
# 212         java  find_pernicious_numbers   100000  0.009667  0.009000
#
#      max time   std dev                 final
# 41   0.264938  0.010839       python - 100000
# 84   0.002433  0.000110        julia - 100000
# 114  0.005131  0.000332            c - 100000
# 143  0.001148  0.000789  c-otimizado - 100000
# 212  0.010000  0.000577         java - 100000
#    language                  function name instance   avg time   min time  \
# 42   python  serial_time_series_processing        0   0.000140   0.000034
# 85    julia  serial_time_series_processing        0  60.428377  59.797597
#
#      max time   std dev       final
# 42   0.000346  0.000178  python - 0
# 85  60.930646  0.577353   julia - 0
