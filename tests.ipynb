# %%
import pandas as pd
import dataframe_image as dfi

# %%
languages = ['python', 'c', 'c-otimizado', 'julia', 'r', 'java']
envs = ['host', 'docker', 'vm']

# %%
df = pd.DataFrame()
for env in envs:
    for lang in languages:
        tmp = pd.read_csv(f'./{env}/results-{env}-{lang}.csv')
        tmp.insert(0, 'env', env)
        tmp.insert(1, 'language', lang)
        df = pd.concat([df, tmp], ignore_index=True)

# %%
df
# Out:
#       env language                   function name    avg time    min time  \
# 0    host   python                copy_matrix_5000   12.374828   12.363077
# 1    host   python                copy_matrix_7000    0.866607    0.859691
# 2    host   python                copy_matrix_9000    1.465662    1.432810
# 3    host   python        look_and_say_sequence_40    1.009808    0.866428
# 4    host   python        look_and_say_sequence_45   21.578715   19.641207
# ..    ...      ...                             ...         ...         ...
# 634    vm     java        evaluate_functions_80000  297.143667  295.281000
# 635    vm     java        evaluate_functions_90000  332.028333  331.685000
# 636    vm     java       evaluate_functions_100000  368.135000  367.729000
# 637    vm     java  find_pernicious_numbers_100000    0.013000    0.010000
# 638    vm     java       find_munchausen_numbers_0    4.876504    4.871771
#
#        max time   std dev
# 0     12.389808  0.013655
# 1      0.872079  0.006319
# 2      1.528046  0.054052
# 3      1.284071  0.237601
# 4     24.093685  2.281718
# ..          ...       ...
# 634  298.629000  1.705597
# 635  332.270000  0.305464
# 636  368.565000  0.418516
# 637    0.015000  0.002646
# 638    4.883373  0.006089
#
# [639 rows x 7 columns]

# %%
df['avg time'].astype(float)
# Out:
# 0       12.374828
# 1        0.866607
# 2        1.465662
# 3        1.009808
# 4       21.578715
#           ...
# 634    297.143667
# 635    332.028333
# 636    368.135000
# 637      0.013000
# 638      4.876504
# Name: avg time, Length: 639, dtype: float64

# %%
def maximum_value_in_column(column):    

    highlight = 'background-color: palegreen;'
    default = ''

    maximum_in_column = column.min()

    # must return one string per cell in this column
    return [highlight if v == maximum_in_column else default for v in column]

# %%
tmp = df.groupby('function name')
for func in df['function name'].unique():
    df_test = tmp.get_group(func).drop(columns=['function name', 'min time', 'max time', 'std dev'])
    df_test.style.set_caption(func)
    df_test = pd.pivot(df_test, index=['language'], columns='env', values='avg time') 
    df_test = df_test.style.apply(maximum_value_in_column, subset=['docker', 'host', 'vm'], axis=0)
    dfi.export(df_test, f'./dfs_tests/{func}.png')
# Out:
# /home/rafaelpontes/.local/lib/python3.10/site-packages/dataframe_image/_pandas_accessor.py:69: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   html = '<div>' + obj.render() + '</div>'
# [0616/104718.417632:WARNING:sandbox_linux.cc(376)] InitializeSandbox() called with multiple threads in process gpu-process.
# [0616/104718.503010:WARNING:bluez_dbus_manager.cc(248)] Floss manager not present, cannot set Floss enable/disable.
# [0616/104718.921388:INFO:headless_shell.cc(660)] Written to file /tmp/tmpb6l7k9xn/temp.png.
# /home/rafaelpontes/.local/lib/python3.10/site-packages/dataframe_image/_pandas_accessor.py:69: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   html = '<div>' + obj.render() + '</div>'
# [0616/104719.288345:WARNING:sandbox_linux.cc(376)] InitializeSandbox() called with multiple threads in process gpu-process.
# [0616/104719.505199:WARNING:bluez_dbus_manager.cc(248)] Floss manager not present, cannot set Floss enable/disable.
# [0616/104719.922109:INFO:headless_shell.cc(660)] Written to file /tmp/tmprksu4jlj/temp.png.
# /home/rafaelpontes/.local/lib/python3.10/site-packages/dataframe_image/_pandas_accessor.py:69: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   html = '<div>' + obj.render() + '</div>'
# [0616/104720.376342:WARNING:sandbox_linux.cc(376)] InitializeSandbox() called with multiple threads in process gpu-process.
# [0616/104721.376635:WARNING:bluez_dbus_manager.cc(248)] Floss manager not present, cannot set Floss enable/disable.
# [0616/104721.806398:INFO:headless_shell.cc(660)] Written to file /tmp/tmppvwydrfy/temp.png.
# /home/rafaelpontes/.local/lib/python3.10/site-packages/dataframe_image/_pandas_accessor.py:69: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   html = '<div>' + obj.render() + '</div>'
# [0616/104722.271271:WARNING:sandbox_linux.cc(376)] InitializeSandbox() called with multiple threads in process gpu-process.
# [0616/104722.474433:WARNING:bluez_dbus_manager.cc(248)] Floss manager not present, cannot set Floss enable/disable.
# [0616/104722.889558:INFO:headless_shell.cc(660)] Written to file /tmp/tmpimjtm0gy/temp.png.
# /home/rafaelpontes/.local/lib/python3.10/site-packages/dataframe_image/_pandas_accessor.py:69: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   html = '<div>' + obj.render() + '</div>'
# [0616/104723.386198:WARNING:sandbox_linux.cc(376)] InitializeSandbox() called with multiple threads in process gpu-process.
# [0616/104723.532966:WARNING:bluez_dbus_manager.cc(248)] Floss manager not present, cannot set Floss enable/disable.
# [0616/104723.957899:INFO:headless_shell.cc(660)] Written to file /tmp/tmp2qeu8ql3/temp.png.
# /home/rafaelpontes/.local/lib/python3.10/site-packages/dataframe_image/_pandas_accessor.py:69: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   html = '<div>' + obj.render() + '</div>'
# [0616/104724.452022:WARNING:sandbox_linux.cc(376)] InitializeSandbox() called with multiple threads in process gpu-process.
# [0616/104724.612228:WARNING:bluez_dbus_manager.cc(248)] Floss manager not present, cannot set Floss enable/disable.
# [0616/104725.017946:INFO:headless_shell.cc(660)] Written to file /tmp/tmplruvxsbv/temp.png.
# /home/rafaelpontes/.local/lib/python3.10/site-packages/dataframe_image/_pandas_accessor.py:69: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   html = '<div>' + obj.render() + '</div>'
# [0616/104725.464426:WARNING:sandbox_linux.cc(376)] InitializeSandbox() called with multiple threads in process gpu-process.
# [0616/104726.477732:WARNING:bluez_dbus_manager.cc(248)] Floss manager not present, cannot set Floss enable/disable.
# [0616/104726.907477:INFO:headless_shell.cc(660)] Written to file /tmp/tmpx90ik477/temp.png.
# /home/rafaelpontes/.local/lib/python3.10/site-packages/dataframe_image/_pandas_accessor.py:69: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   html = '<div>' + obj.render() + '</div>'
# [0616/104727.369855:WARNING:sandbox_linux.cc(376)] InitializeSandbox() called with multiple threads in process gpu-process.
# [0616/104729.370458:WARNING:bluez_dbus_manager.cc(248)] Floss manager not present, cannot set Floss enable/disable.
# [0616/104729.800507:INFO:headless_shell.cc(660)] Written to file /tmp/tmps1r_cke5/temp.png.
# /home/rafaelpontes/.local/lib/python3.10/site-packages/dataframe_image/_pandas_accessor.py:69: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   html = '<div>' + obj.render() + '</div>'
# [0616/104730.293884:WARNING:sandbox_linux.cc(376)] InitializeSandbox() called with multiple threads in process gpu-process.
# [0616/104730.435580:WARNING:bluez_dbus_manager.cc(248)] Floss manager not present, cannot set Floss enable/disable.
# [0616/104730.875196:INFO:headless_shell.cc(660)] Written to file /tmp/tmp2papqh73/temp.png.
# /home/rafaelpontes/.local/lib/python3.10/site-packages/dataframe_image/_pandas_accessor.py:69: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   html = '<div>' + obj.render() + '</div>'
# [0616/104731.329372:WARNING:sandbox_linux.cc(376)] InitializeSandbox() called with multiple threads in process gpu-process.
# [0616/104732.963826:WARNING:bluez_dbus_manager.cc(248)] Floss manager not present, cannot set Floss enable/disable.
# [0616/104733.393597:INFO:headless_shell.cc(660)] Written to file /tmp/tmpqfi4ldvl/temp.png.
# /home/rafaelpontes/.local/lib/python3.10/site-packages/dataframe_image/_pandas_accessor.py:69: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   html = '<div>' + obj.render() + '</div>'
# [0616/104733.847528:WARNING:sandbox_linux.cc(376)] InitializeSandbox() called with multiple threads in process gpu-process.
# [0616/104734.082459:WARNING:bluez_dbus_manager.cc(248)] Floss manager not present, cannot set Floss enable/disable.
# [0616/104734.521172:INFO:headless_shell.cc(660)] Written to file /tmp/tmpvnmd9brp/temp.png.
# /home/rafaelpontes/.local/lib/python3.10/site-packages/dataframe_image/_pandas_accessor.py:69: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   html = '<div>' + obj.render() + '</div>'
# [0616/104734.951132:WARNING:sandbox_linux.cc(376)] InitializeSandbox() called with multiple threads in process gpu-process.
# [0616/104735.301393:WARNING:bluez_dbus_manager.cc(248)] Floss manager not present, cannot set Floss enable/disable.
# [0616/